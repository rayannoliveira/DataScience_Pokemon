# %%
import pandas as pd

# %%
df= pd.read_csv('pokemon_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#Find all types of Type 1 and putting to Series Type_of_pokmon
Type_of_pokmon = df['Type 1']

# %%
#Drop the duplicates
Type_of_pokmon.drop_duplicates(inplace=True)
Type_of_pokmon
# Out:
# 0         Grass
# 4          Fire
# 9         Water
# 13          Bug
# 20       Normal
# 28       Poison
# 30     Electric
# 32       Ground
# 40        Fairy
# 61     Fighting
# 68      Psychic
# 80         Rock
# 99        Ghost
# 133         Ice
# 159      Dragon
# 212        Dark
# 223       Steel
# 702      Flying
# Name: Type 1, dtype: object

# %%
# the shape of Type_of_pokmon
Type_of_pokmon.shape[0]
# Out:
# 18

# %%
#Redefind the index 
Type_of_pokmon.index = range(Type_of_pokmon.shape[0])
Type_of_pokmon
# Out:
# 0        Grass
# 1         Fire
# 2        Water
# 3          Bug
# 4       Normal
# 5       Poison
# 6     Electric
# 7       Ground
# 8        Fairy
# 9     Fighting
# 10     Psychic
# 11        Rock
# 12       Ghost
# 13         Ice
# 14      Dragon
# 15        Dark
# 16       Steel
# 17      Flying
# Name: Type 1, dtype: object

# %%
#How many pokemon has type 1

df['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
df['Type 1'].value_counts(normalize = True) * 100
# Out:
# Water       14.000
# Normal      12.250
# Grass        8.750
# Bug          8.625
# Psychic      7.125
# Fire         6.500
# Electric     5.500
# Rock         5.500
# Dragon       4.000
# Ground       4.000
# Ghost        4.000
# Dark         3.875
# Poison       3.500
# Steel        3.375
# Fighting     3.375
# Ice          3.000
# Fairy        2.125
# Flying       0.500
# Name: Type 1, dtype: float64

# %%
#Frequence and the percentage

frequence = df['Type 1'].value_counts()

percentage = df['Type 1'].value_counts(normalize = True) * 100

# %%
#creating a DataFrame of frequence and percentage 

df_frequence_qualitative = pd.DataFrame({'Frequence': frequence, 'Percentage (%)': percentage})
df_frequence_qualitative
# Out:
#           Frequence  Percentage (%)
# Water           112          14.000
# Normal           98          12.250
# Grass            70           8.750
# Bug              69           8.625
# Psychic          57           7.125
# Fire             52           6.500
# Electric         44           5.500
# Rock             44           5.500
# Dragon           32           4.000
# Ground           32           4.000
# Ghost            32           4.000
# Dark             31           3.875
# Poison           28           3.500
# Steel            27           3.375
# Fighting         27           3.375
# Ice              24           3.000
# Fairy            17           2.125
# Flying            4           0.500

# %%
#Rename the column

df_frequence_qualitative.rename_axis('Pokemon Type', axis= 'columns', inplace=True)
df_frequence_qualitative
# Out:
# Pokemon Type  Frequence  Percentage (%)
# Water               112          14.000
# Normal               98          12.250
# Grass                70           8.750
# Bug                  69           8.625
# Psychic              57           7.125
# Fire                 52           6.500
# Electric             44           5.500
# Rock                 44           5.500
# Dragon               32           4.000
# Ground               32           4.000
# Ghost                32           4.000
# Dark                 31           3.875
# Poison               28           3.500
# Steel                27           3.375
# Fighting             27           3.375
# Ice                  24           3.000
# Fairy                17           2.125
# Flying                4           0.500

# %%
df_frequence_qualitative['Frequence'].plot.bar(width=1, color = 'blue', alpha = 0.2, figsize= (12, 6))
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ## Grouping Type 1 and pokemon generation

# %%
frequence = pd.crosstab(df['Type 1'], df['Generation'])
frequence
# Out:
# Generation   1   2   3   4   5   6
# Type 1
# Bug         14  12  12  10  18   3
# Dark         0   6   6   3  13   3
# Dragon       3   0  12   4   9   4
# Electric     9   7   5  12   8   3
# Fairy        2   5   0   1   0   9
# Fighting     7   2   5   3   7   3
# Fire        14   8   8   5   9   8
# Flying       0   0   0   0   2   2
# Ghost        4   1   5   7   5  10
# Grass       13   9  13  15  15   5
# Ground       8   3   7   4  10   0
# Ice          2   4   7   3   6   2
# Normal      24  15  18  18  19   4
# Poison      14   1   3   6   2   2
# Psychic     11   7  12   8  14   5
# Rock        10   5   8   6   6   9
# Steel        0   3  12   3   4   5
# Water       31  18  27  13  18   5

# %%
percentage =  pd.crosstab(df['Type 1'], df['Generation'], normalize = True) * 100
percentage
# Out:
# Generation      1      2      3      4      5      6
# Type 1
# Bug         1.750  1.500  1.500  1.250  2.250  0.375
# Dark        0.000  0.750  0.750  0.375  1.625  0.375
# Dragon      0.375  0.000  1.500  0.500  1.125  0.500
# Electric    1.125  0.875  0.625  1.500  1.000  0.375
# Fairy       0.250  0.625  0.000  0.125  0.000  1.125
# Fighting    0.875  0.250  0.625  0.375  0.875  0.375
# Fire        1.750  1.000  1.000  0.625  1.125  1.000
# Flying      0.000  0.000  0.000  0.000  0.250  0.250
# Ghost       0.500  0.125  0.625  0.875  0.625  1.250
# Grass       1.625  1.125  1.625  1.875  1.875  0.625
# Ground      1.000  0.375  0.875  0.500  1.250  0.000
# Ice         0.250  0.500  0.875  0.375  0.750  0.250
# Normal      3.000  1.875  2.250  2.250  2.375  0.500
# Poison      1.750  0.125  0.375  0.750  0.250  0.250
# Psychic     1.375  0.875  1.500  1.000  1.750  0.625
# Rock        1.250  0.625  1.000  0.750  0.750  1.125
# Steel       0.000  0.375  1.500  0.375  0.500  0.625
# ...

# %%
df['Generation'].value_counts()
# Out:
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: Generation, dtype: int64
